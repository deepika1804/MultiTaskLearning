# %%
import keras
import math
from keras.models import Sequential
from keras.optimizers import SGD,Adam
from keras.layers import GlobalAveragePooling2D, Add, concatenate, Lambda, Input, Layer, Dense, Conv2D 
from keras.layers import MaxPooling2D, AveragePooling2D, ZeroPadding2D, Dropout, Flatten, merge, Reshape, Activation
from keras.layers.normalization import BatchNormalization
from keras.models import Model
from keras import backend as K
from keras.regularizers import l2
from keras.utils import np_utils, Sequence
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.preprocessing.image import apply_transform, transform_matrix_offset_center, flip_axis
from keras.applications.imagenet_utils import preprocess_input, _obtain_input_shape
from keras.initializers import he_normal
#import matplotlib.pyplot as plt
#from sklearn.metrics import log_loss

# from load_cifar10 import load_cifar10_data
import csv
import cv2
import os
import numpy as np
from scipy.io import loadmat, savemat
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-c88e90befe2f> in <module>()
#      11 from keras.utils import np_utils, Sequence
#      12 from keras.callbacks import ModelCheckpoint, LearningRateScheduler
# ---> 13 from keras.applications.imagenet_utils import preprocess_input, _obtain_input_shape
#      14 from keras.initializers import he_normal
#      15 #import matplotlib.pyplot as plt
#
# ImportError: cannot import name '_obtain_input_shape'

# %%
import keras.backend as K
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, Activation

def densenet(num_classes, input_shape):
    
    def NiNBlock(kernel, mlps, strides):
        def inner(x):
            l = Conv2D(mlps[0], kernel, strides=strides, padding='same')(x)
            l = Activation('relu')(l)
            for size in mlps[1:]:
                l = Conv2D(size, 1, strides=[1,1])(l)
                l = Activation('relu')(l)
            return l
        return inner


    def get_model(img_rows, img_cols,rgb):
        img = Input(shape=(img_rows, img_cols, rgb))
        l1 = NiNBlock(7, [96, 96, 96], [2,2])(img)
        l1 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(l1)
    #     l1 = Dropout(0.7)(l1)

        l2 = NiNBlock(5, [256, 256, 256], [2,2])(l1)
        l2 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(l2)
    #     l2 = Dropout(0.7)(l2)

        l3 = NiNBlock(3, [512, 512, 512], [1,1])(l2)

        l4 = NiNBlock(3, [1024, 1024, 512,384], [1,1])(l3)
        l5 = NiNBlock(3, [512, 512, 512], [2,2])(l4)
        l5 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(l5)
        l5 = Flatten()(l5)
        l6 = Dense(1024)(l5)
        l7 = Dense(1024)(l6)
        #add dense according to attribute layer. (for each attribute 1 or 0)
#         l8 = Dense(1)(l7)
        l9 = Activation('softmax')(l7) # or sigmoid

        model = Model(inputs=img, outputs=l9)
        return model
    img_rows = input_shape[0];
    img_cols = input_shape[1];
    rgb = input_shape[2];
    model = get_model(img_rows,img_cols,rgb)
    return model

# %%
class TopSequence(Sequence):
# class TopSequence():
    def __init__(self, x, y, batch_size, img_size = [32,32,3], test_mode=False):
        print("init")
        self.x = x
        self.y = y
        self.batch_size = batch_size
        self.img_size = img_size
        self.test_mode = test_mode
        self.data_size = x.shape[0]
        print(self.data_size)

    def __len__(self):
        print("len")
        return self.data_size // self.batch_size

    def __getitem__(self,batch_idx):
        print("called")
        if (batch_idx + 1) * self.batch_size - 1 >= self.data_size:
            batch_idx = np.random.randint(self.data_size - 1)

        # Create empty arrays to contain batch of images and labels
        batch_images = np.zeros((self.batch_size, self.img_size[0], self.img_size[1], self.img_size[2]))
        batch_top_outer_category = np.zeros((self.batch_size,5), dtype=np.uint32)

        for b in range(self.batch_size):
            img_path = self.x[batch_idx * self.batch_size + b]
            im = cv2.imread(img_path)
            im = cv2.resize(im,(self.img_size[0], self.img_size[1]))
            im = im / 255.0
#             im = augment_image(im)
#             im = im * 255.0

            batch_images[b, :, :, :] = im                                                    #storing image
            batch_top_outer_category[b, :] = np_utils.to_categorical(int(self.y[batch_idx * self.batch_size + b]), 5)
        
        batch_images = preprocess_input(batch_images)
        print(batch_images.shape)
        return batch_images, batch_top_outer_category#[batch_person_direction, batch_top_outer_category, batch_top_outer_neck_style, batch_top_outer_fit, batch_top_outer_formality, batch_top_outer_design, batch_top_outer_length, batch_top_outer_sleeve_length, batch_top_outer_reflection, batch_presence_of_top_inner, batch_top_inner_category, batch_top_inner_neck_style, batch_top_inner_fit, batch_top_inner_formality, batch_top_inner_design, batch_top_inner_length, batch_top_inner_sleeve_length, batch_top_inner_reflection, batch_top_outer_color, batch_top_inner_color]# + batch_top_outer_color + batch_top_inner_color

# %%
import csv
import cv2
import os
import numpy as np
from scipy.io import loadmat, savemat
img_rows, img_cols = 112, 112
channel = 3
num_classes = 18
batch_size = 32
nb_epoch = 150

X_train = []
X_valid = []
Y_train = []
Y_valid = []

with open("top_outer_category_balanced_train.csv") as file_obj:
    reader = csv.DictReader(file_obj, delimiter=',')
    for line in reader:
        X_train.append(line['x'])
        Y_train.append(line['y'])

with open("top_outer_category_balanced_test.csv") as file_obj:
    reader = csv.DictReader(file_obj, delimiter=',')
    for line in reader:
        X_valid.append(line['x'])
        Y_valid.append(line['y'])

X_train = np.array(X_train)
X_valid = np.array(X_valid)
Y_train = np.array(Y_train)
Y_valid = np.array(Y_valid)

model = densenet(num_classes, input_shape=(32,32,3))

top_outter_category_layer = Dense(5, activation='softmax', name='top_outer_category_pred')(model.output)

model = Model(model.input,top_outter_category_layer,name="final")
print(model.summary())

ada = Adam(lr = 0.0001,decay=0.0005)
model.compile(loss=['categorical_crossentropy'],optimizer=ada,metrics=['accuracy'])

#model.fit(x_train, y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))

train_seq = TopSequence(X_train[0:5], Y_train[0:5], batch_size, img_size=[32,32,3])
#val_seq = TopSequence(X_valid[1:2], Y_valid[1:2], batch_size, img_size=[32,32,3])

model.fit_generator(
    train_seq,
    steps_per_epoch=len(train_seq),
    epochs=nb_epoch)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_36 (InputLayer)        (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_545 (Conv2D)          (None, 16, 16, 96)        14208
# _________________________________________________________________
# activation_576 (Activation)  (None, 16, 16, 96)        0
# _________________________________________________________________
# conv2d_546 (Conv2D)          (None, 16, 16, 96)        9312
# _________________________________________________________________
# activation_577 (Activation)  (None, 16, 16, 96)        0
# _________________________________________________________________
# conv2d_547 (Conv2D)          (None, 16, 16, 96)        9312
# _________________________________________________________________
# activation_578 (Activation)  (None, 16, 16, 96)        0
# _________________________________________________________________
# max_pooling2d_103 (MaxPoolin (None, 8, 8, 96)          0
# _________________________________________________________________
# conv2d_548 (Conv2D)          (None, 4, 4, 256)         614656
# _________________________________________________________________
# activation_579 (Activation)  (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_549 (Conv2D)          (None, 4, 4, 256)         65792
# _________________________________________________________________
# activation_580 (Activation)  (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_550 (Conv2D)          (None, 4, 4, 256)         65792
# _________________________________________________________________
# activation_581 (Activation)  (None, 4, 4, 256)         0
# _________________________________________________________________
# max_pooling2d_104 (MaxPoolin (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_551 (Conv2D)          (None, 2, 2, 512)         1180160
# _________________________________________________________________
# activation_582 (Activation)  (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_552 (Conv2D)          (None, 2, 2, 512)         262656
# _________________________________________________________________
# activation_583 (Activation)  (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_553 (Conv2D)          (None, 2, 2, 512)         262656
# _________________________________________________________________
# activation_584 (Activation)  (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_554 (Conv2D)          (None, 2, 2, 1024)        4719616
# _________________________________________________________________
# activation_585 (Activation)  (None, 2, 2, 1024)        0
# _________________________________________________________________
# conv2d_555 (Conv2D)          (None, 2, 2, 1024)        1049600
# _________________________________________________________________
# activation_586 (Activation)  (None, 2, 2, 1024)        0
# _________________________________________________________________
# conv2d_556 (Conv2D)          (None, 2, 2, 512)         524800
# _________________________________________________________________
# activation_587 (Activation)  (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_557 (Conv2D)          (None, 2, 2, 384)         196992
# _________________________________________________________________
# activation_588 (Activation)  (None, 2, 2, 384)         0
# _________________________________________________________________
# conv2d_558 (Conv2D)          (None, 1, 1, 512)         1769984
# _________________________________________________________________
# activation_589 (Activation)  (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_559 (Conv2D)          (None, 1, 1, 512)         262656
# _________________________________________________________________
# activation_590 (Activation)  (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_560 (Conv2D)          (None, 1, 1, 512)         262656
# _________________________________________________________________
# activation_591 (Activation)  (None, 1, 1, 512)         0
# _________________________________________________________________
# max_pooling2d_105 (MaxPoolin (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_87 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# dense_88 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# activation_592 (Activation)  (None, 1024)              0
# _________________________________________________________________
# top_outer_category_pred (Den (None, 5)                 5125
# =================================================================
# Total params: 12,850,885
# Trainable params: 12,850,885
# Non-trainable params: 0
# _________________________________________________________________
# None
# init
# 5
# len
# len
# Epoch 1/1
# called
# (5, 32, 32, 3)
# called
# (5, 32, 32, 3)
# 1/1 [==============================] - 8s 8s/step - loss: 1.6103 - acc: 0.0000e+00

# %%
X_train[0:1]

# %%
import keras
import math
from keras.models import Sequential
from keras.optimizers import SGD,Adam
from keras.layers import GlobalAveragePooling2D, Add, concatenate, Lambda, Input, Layer, Dense, Conv2D 
from keras.layers import MaxPooling2D, AveragePooling2D, ZeroPadding2D, Dropout, Flatten, merge, Reshape, Activation
from keras.layers.normalization import BatchNormalization
from keras.models import Model
from keras import backend as K
from keras.regularizers import l2
from keras.utils import np_utils, Sequence
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
# from keras.preprocessing.image import apply_transform, transform_matrix_offset_center, flip_axis
# from keras.applications.imagenet_utils import preprocess_input, _obtain_input_shape
from keras.initializers import he_normal
#import matplotlib.pyplot as plt
#from sklearn.metrics import log_loss

# from load_cifar10 import load_cifar10_data
import csv
import cv2
import os
import numpy as np
from scipy.io import loadmat, savemat
import keras.backend as K
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, Activation

def densenet(num_classes, input_shape):
    
    def NiNBlock(kernel, mlps, strides):
        def inner(x):
            l = Conv2D(mlps[0], kernel, strides=strides, padding='same')(x)
            l = Activation('relu')(l)
            for size in mlps[1:]:
                l = Conv2D(size, 1, strides=[1,1])(l)
                l = Activation('relu')(l)
            return l
        return inner


    def get_model(img_rows, img_cols,rgb):
        img = Input(shape=(img_rows, img_cols, rgb))
        l1 = NiNBlock(7, [96, 96, 96], [2,2])(img)
        l1 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(l1)
    #     l1 = Dropout(0.7)(l1)

        l2 = NiNBlock(5, [256, 256, 256], [2,2])(l1)
        l2 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(l2)
    #     l2 = Dropout(0.7)(l2)

        l3 = NiNBlock(3, [512, 512, 512], [1,1])(l2)

        l4 = NiNBlock(3, [1024, 1024, 512,384], [1,1])(l3)
        l5 = NiNBlock(3, [512, 512, 512], [2,2])(l4)
        l5 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same')(l5)
        l5 = Flatten()(l5)
        l6 = Dense(1024)(l5)
        l7 = Dense(1024)(l6)
        #add dense according to attribute layer. (for each attribute 1 or 0)
#         l8 = Dense(1)(l7)
        l9 = Activation('softmax')(l7) # or sigmoid

        model = Model(inputs=img, outputs=l9)
        return model
    img_rows = input_shape[0];
    img_cols = input_shape[1];
    rgb = input_shape[2];
    model = get_model(img_rows,img_cols,rgb)
    return model


class TopSequence(Sequence):
# class TopSequence():
    def __init__(self, x, y, batch_size, img_size = [32,32,3], test_mode=False):
        print("init")
        self.x = x
        self.y = y
        self.batch_size = batch_size
        self.img_size = img_size
        self.test_mode = test_mode
        self.data_size = x.shape[0]
        print(self.data_size)

    def __len__(self):
        print("len")
        return self.data_size // self.batch_size

    def __getitem__(self,batch_idx):
        print("called")
        if (batch_idx + 1) * self.batch_size - 1 >= self.data_size:
            batch_idx = np.random.randint(self.data_size - 1)

        # Create empty arrays to contain batch of images and labels
        batch_images = np.zeros((self.batch_size, self.img_size[0], self.img_size[1], self.img_size[2]))
        batch_top_outer_category = np.zeros((self.batch_size,5), dtype=np.uint32)

        for b in range(self.batch_size):
            img_path = self.x[batch_idx * self.batch_size + b]
            im = cv2.imread(img_path)
            im = cv2.resize(im,(self.img_size[0], self.img_size[1]))
            im = im / 255.0
#             im = augment_image(im)
#             im = im * 255.0

            batch_images[b, :, :, :] = im                                                    #storing image
            batch_top_outer_category[b, :] = np_utils.to_categorical(int(self.y[batch_idx * self.batch_size + b]), 5)
        
        batch_images = preprocess_input(batch_images)
        print(batch_images.shape)
        return batch_images, batch_top_outer_category


img_rows, img_cols = 112, 112
channel = 3
num_classes = 18
batch_size = 32
nb_epoch = 150

X_train = []
X_valid = []
Y_train = []
Y_valid = []

with open("/data/ILRW/top_outer_category_balanced_train.csv") as file_obj:
    reader = csv.DictReader(file_obj, delimiter=',')
    for line in reader:
        X_train.append(line['x'])
        Y_train.append(line['y'])

with open("/data/ILRW/top_outer_category_balanced_test.csv") as file_obj:
    reader = csv.DictReader(file_obj, delimiter=',')
    for line in reader:
        X_valid.append(line['x'])
        Y_valid.append(line['y'])

X_train = np.array(X_train)
X_valid = np.array(X_valid)
Y_train = np.array(Y_train)
Y_valid = np.array(Y_valid)

model = densenet(num_classes, input_shape=(32,32,3))

top_outter_category_layer = Dense(5, activation='softmax', name='top_outer_category_pred')(model.output)

model = Model(model.input,top_outter_category_layer,name="final")
print(model.summary())

ada = Adam(lr = 0.0001,decay=0.0005)
model.compile(loss=['categorical_crossentropy'],optimizer=ada,metrics=['accuracy'])

#model.fit(x_train, y_train,batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(x_test, y_test))

train_seq = TopSequence(X_train, Y_train, batch_size, img_size=[32,32,3])
#val_seq = TopSequence(X_valid[1:2], Y_valid[1:2], batch_size, img_size=[32,32,3])

model.fit_generator(
    train_seq,
    steps_per_epoch=len(train_seq),
    epochs=nb_epoch)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_37 (InputLayer)        (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_561 (Conv2D)          (None, 16, 16, 96)        14208
# _________________________________________________________________
# activation_593 (Activation)  (None, 16, 16, 96)        0
# _________________________________________________________________
# conv2d_562 (Conv2D)          (None, 16, 16, 96)        9312
# _________________________________________________________________
# activation_594 (Activation)  (None, 16, 16, 96)        0
# _________________________________________________________________
# conv2d_563 (Conv2D)          (None, 16, 16, 96)        9312
# _________________________________________________________________
# activation_595 (Activation)  (None, 16, 16, 96)        0
# _________________________________________________________________
# max_pooling2d_106 (MaxPoolin (None, 8, 8, 96)          0
# _________________________________________________________________
# conv2d_564 (Conv2D)          (None, 4, 4, 256)         614656
# _________________________________________________________________
# activation_596 (Activation)  (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_565 (Conv2D)          (None, 4, 4, 256)         65792
# _________________________________________________________________
# activation_597 (Activation)  (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_566 (Conv2D)          (None, 4, 4, 256)         65792
# _________________________________________________________________
# activation_598 (Activation)  (None, 4, 4, 256)         0
# _________________________________________________________________
# max_pooling2d_107 (MaxPoolin (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_567 (Conv2D)          (None, 2, 2, 512)         1180160
# _________________________________________________________________
# activation_599 (Activation)  (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_568 (Conv2D)          (None, 2, 2, 512)         262656
# _________________________________________________________________
# activation_600 (Activation)  (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_569 (Conv2D)          (None, 2, 2, 512)         262656
# _________________________________________________________________
# activation_601 (Activation)  (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_570 (Conv2D)          (None, 2, 2, 1024)        4719616
# _________________________________________________________________
# activation_602 (Activation)  (None, 2, 2, 1024)        0
# _________________________________________________________________
# conv2d_571 (Conv2D)          (None, 2, 2, 1024)        1049600
# _________________________________________________________________
# activation_603 (Activation)  (None, 2, 2, 1024)        0
# _________________________________________________________________
# conv2d_572 (Conv2D)          (None, 2, 2, 512)         524800
# _________________________________________________________________
# activation_604 (Activation)  (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_573 (Conv2D)          (None, 2, 2, 384)         196992
# _________________________________________________________________
# activation_605 (Activation)  (None, 2, 2, 384)         0
# _________________________________________________________________
# conv2d_574 (Conv2D)          (None, 1, 1, 512)         1769984
# _________________________________________________________________
# activation_606 (Activation)  (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_575 (Conv2D)          (None, 1, 1, 512)         262656
# _________________________________________________________________
# activation_607 (Activation)  (None, 1, 1, 512)         0
# _________________________________________________________________
# conv2d_576 (Conv2D)          (None, 1, 1, 512)         262656
# _________________________________________________________________
# activation_608 (Activation)  (None, 1, 1, 512)         0
# _________________________________________________________________
# max_pooling2d_108 (MaxPoolin (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_89 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# dense_90 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# activation_609 (Activation)  (None, 1024)              0
# _________________________________________________________________
# top_outer_category_pred (Den (None, 5)                 5125
# =================================================================
# Total params: 12,850,885
# Trainable params: 12,850,885
# Non-trainable params: 0
# _________________________________________________________________
# None
# init
# 37553
# len
# len
# Epoch 1/150
# called
# called
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-81-c412cb09e47d> in <module>()
#     159     train_seq,
#     160     steps_per_epoch=len(train_seq),
# --> 161     epochs=nb_epoch)
#     162
#
# /anaconda3/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# /anaconda3/lib/python3.6/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     179             batch_index = 0
#     180             while steps_done < steps_per_epoch:
# --> 181                 generator_output = next(output_generator)
#     182
#     183                 if not hasattr(generator_output, '__len__'):
#
# /anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py in get(self)
#     599         except Exception as e:
#     600             self.stop()
# --> 601             six.reraise(*sys.exc_info())
#     602
#     603
#
# /anaconda3/lib/python3.6/site-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# /anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py in get(self)
#     593         try:
#     594             while self.is_running():
# --> 595                 inputs = self.queue.get(block=True).get()
#     596                 self.queue.task_done()
#     597                 if inputs is not None:
#
# /anaconda3/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     642             return self._value
#     643         else:
# --> 644             raise self._value
#     645
#     646     def _set(self, i, obj):
#
# /anaconda3/lib/python3.6/multiprocessing/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     117         job, i, func, args, kwds = task
#     118         try:
# --> 119             result = (True, func(*args, **kwds))
#     120         except Exception as e:
#     121             if wrap_exception and func is not _helper_reraises_exception:
#
# /anaconda3/lib/python3.6/site-packages/keras/utils/data_utils.py in get_index(uid, i)
#     399         The value at index `i`.
#     400     """
# --> 401     return _SHARED_SEQUENCES[uid][i]
#     402
#     403
#
# <ipython-input-81-c412cb09e47d> in __getitem__(self, batch_idx)
#     100             img_path = self.x[batch_idx * self.batch_size + b]
#     101             im = cv2.imread(img_path)
# --> 102             im = cv2.resize(im,(self.img_size[0], self.img_size[1]))
#     103             im = im / 255.0
#     104 #             im = augment_image(im)
#
# error: /Users/travis/build/skvark/opencv-python/opencv/modules/imgproc/src/resize.cpp:4044: error: (-215) ssize.width > 0 && ssize.height > 0 in function resize
